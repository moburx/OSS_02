# %%
#---예제01---
a = [1,2,3]
b = a
a.append(4)
print(b)
# Out:
# [1, 2, 3, 4]

# %%
#---예제02---
class Gizmo:
   def __init__(self):
        print('Gizmo id: %d' % id(self))
x = Gizmo()
print(dir())
# Out:
# Gizmo id: 133044523959456
# ['Gizmo', 'In', 'Out', '_', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '_dh', '_i', '_i1', '_i2', '_i3', '_i4', '_i5', '_i6', '_ih', '_ii', '_iii', '_oh', 'a', 'b', 'exit', 'get_ipython', 'quit', 'x']

# %%
#---예제03---
charles = {'name': 'Charles L. Dodgson', 'born': 1832}
lewis = charles
print(lewis is charles)
print(id(charles), id(lewis))
lewis['balance'] = 950
print(charles)
# Out:
# True
# 133044504432768 133044504432768
# {'name': 'Charles L. Dodgson', 'born': 1832, 'balance': 950}

# %%
#---예제04---
alex = {'name': 'Charles L. Dodgson', 'born': 1832, 'balance': 950}
print(alex == charles)
print(alex is charles)
# Out:
# True
# False

# %%
#---예제05---
t1 = (1, 2, [30, 40])
t2 = (1, 2, [30, 40])
t1 == t2, t1 is t2
print(t1 == t2)
print(id(t1[-1]))
print(t1[-1].append(99))
print(t1, id(t1[-1]))
print(t1 == t2)
# Out:
# True
# 133044504072768
# None
# (1, 2, [30, 40, 99]) 133044504072768
# False

# %%
#---예제06---
l1 = [3, [66, 55, 44], (7, 8, 9)]
l2 = list(l1)

l1.append(100)
l1[1].remove(55)

print("l1:", l1)
print("l2:", l2)

l2[1] += [33, 22]
l2[2] += (10, 11)

print("l1:", l1)
print("l2:", l2)
# Out:
# l1: [3, [66, 44], (7, 8, 9), 100]
# l2: [3, [66, 44], (7, 8, 9)]
# l1: [3, [66, 44, 33, 22], (7, 8, 9), 100]
# l2: [3, [66, 44, 33, 22], (7, 8, 9, 10, 11)]

# %%
#---예제07---
class Bus:
    def __init__(self, passengers=None):
        if passengers is None:
            self.passengers = []
        else:
            self.passengers = list(passengers)

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)

# %%
#---예제08--
import copy

class Bus:
    def __init__(self, passengers=None):
        if passengers is None:
            self.passengers = []
        else:
            self.passengers = list(passengers)

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)


bus1 = Bus(['Alice', 'Bill', 'Claire', 'David'])
bus2 = copy.copy(bus1)
bus3 = copy.deepcopy(bus1)
print(id(bus1), id(bus2), id(bus3))
bus1.drop('Bill')
print(bus1.passengers, bus2.passengers, bus3.passengers)
print(id(bus1.passengers), id(bus2.passengers), id(bus3.passengers))
# Out:
# 133044523611680 133044523962432 133044510554400
# ['Alice', 'Claire', 'David'] ['Alice', 'Claire', 'David'] ['Alice', 'Bill', 'Claire', 'David']
# 133044504436224 133044504436224 133044504425088

# %%
#---예제09---
import copy

a = [10, 20]
b = [a, 30]
a.append(b)

print(a)

c = copy.deepcopy(a)
print(c)
# Out:
# [10, 20, [[...], 30]]
# [10, 20, [[...], 30]]

# %%
#---예제10---
def f(a, b):
    a += b
    return a

a = [1, 2]
b = [3, 4]
print(f(a, b), (a, b))

x = 1
y = 2
print(f(x, y), (x, y))

t = (10, 20)
u = (30, 40)
print(f(t, u), (t, u))
# Out:
# [1, 2, 3, 4] ([1, 2, 3, 4], [3, 4])
# 3 (1, 2)
# (10, 20, 30, 40) ((10, 20), (30, 40))

# %%
#---예제11---
class HauntedBus:
    """유령 승객이 출몰하는 버스 모델"""

    def __init__(self, passengers=[]):
        self.passengers = passengers

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)

# %%
#---예제12---
class HauntedBus:
    """유령 승객이 출몰하는 버스 모델"""

    def __init__(self, passengers=[]):
        self.passengers = passengers

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)


bus1 = HauntedBus(['Alice', 'Bill'])
print(bus1.passengers)

bus3 = HauntedBus()
print(bus3.passengers)

bus1.pick('Charlie')
bus1.drop('Alice')
print(bus1.passengers)

bus3.pick('Dave')
print(bus3.passengers)

bus2 = HauntedBus()
bus2.pick('Carrie')
print(bus2.passengers)

print(bus2.passengers is bus3.passengers)

print(bus1.passengers)
# Out:
# ['Alice', 'Bill']
# []
# ['Bill', 'Charlie']
# ['Dave']
# ['Dave', 'Carrie']
# True
# ['Bill', 'Charlie']

# %%
#---예제13---
class TwilightBus:
    """승객이 사라지게 만드는 버스 모델"""

    def __init__(self, passengers=None):
        if passengers is None:
            self.passengers = []
        else:
            self.passengers = passengers

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)

# %%
#---예제14---
class TwilightBus:
    """승객이 사라지게 만드는 버스 모델"""

    def __init__(self, passengers=None):
        if passengers is None:
            self.passengers = []
        else:
            self.passengers = passengers

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)
basketball_team = ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']

bus = TwilightBus(basketball_team)

bus.drop('Tina')
bus.drop('Pat')

print(basketball_team)
# Out:
# ['Sue', 'Maya', 'Diana']

# %%
#---예제15---
class TwilightBus:
    """승객이 사라지지 않는 안전한 버스 모델"""

    def __init__(self, passengers=None):
        if passengers is None:
            self.passengers = []
        else:
            self.passengers = list(passengers)

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)

# %%
#---예제16---
class TwilightBus:
    """승객이 사라지지 않는 안전한 버스 모델"""

    def __init__(self, passengers=None):
        if passengers is None:
            self.passengers = []
        else:
            self.passengers = list(passengers)

    def pick(self, name):
        self.passengers.append(name)

    def drop(self, name):
        self.passengers.remove(name)
basketball_team = ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']
bus = TwilightBus(basketball_team)

bus.drop('Tina')
bus.drop('Pat')

print(basketball_team)
# Out:
# ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']

# %%
#---예제17---
import weakref

s1 = {1, 2, 3}
s2 = s1

def bye():
    print('Gone with the wind...')

ender = weakref.finalize(s1, bye)

print(ender.alive)
del s1
print(ender.alive)
s2 = 'spam'
print(ender.alive)
# Out:
# True
# True
# Gone with the wind...
# False
